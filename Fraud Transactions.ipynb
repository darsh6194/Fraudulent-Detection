# %%
# Assignment Given By Team Accredian Thanks For Giving An Opportunity To Showcase My Talents To You Hope You Find It Suitable.
# Submitted By : M Darshan
# The Comments In This Notepad Explains The Step For Better Understanding


import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

def load_data(file_path):
    # Load the data
    data = pd.read_csv(file_path)
    return data

def explore_data(data):
    # Display head, tail, shape, and missing values
    print("Head:")
    print(data.head())
    
    print("\nTail:")
    print(data.tail())
    
    print("\nShape:")
    print(data.shape)
    
    print("\nMissing Values:")
    print(data.isna().sum())

    # Display value counts for isFraud and isFlaggedFraud
    print("\nisFraud Value Counts:")
    print(data.isFraud.value_counts())

    print("\nisFlaggedFraud Value Counts:")
    print(data.isFlaggedFraud.value_counts())

def preprocess_data(data):
    # Drop unnecessary columns
    data = data.drop(['nameOrig', 'nameDest'], axis=1)

    # Encode categorical variable 'type'
    label_encoder = LabelEncoder()
    data['type'] = label_encoder.fit_transform(data['type'])

    return data

def split_and_standardize_data(X, y):
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40, random_state=42)

    # Standardize features
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)

    return X_train, X_test, y_train, y_test

def train_and_evaluate_naive_bayes(X_train, X_test, y_train, y_test):
    # Create a Gaussian Naive Bayes classifier
    gnb = GaussianNB()

    # Train the model using the training sets
    gnb.fit(X_train, y_train)

    # Predict the response for the test dataset
    y_pred = gnb.predict(X_test)

    # Evaluate the model
    accuracy = metrics.accuracy_score(y_test, y_pred)
    print("Naive Bayes Accuracy:", accuracy)
    

def train_and_evaluate_logistic_regression(X_train, X_test, y_train, y_test):
    # Create a Logistic Regression classifier
    classifier = LogisticRegression(random_state=0)

    # Train the model using the training sets
    classifier.fit(X_train, y_train)

    # Predict the response for the test dataset
    y_pred = classifier.predict(X_test)

    # Evaluate the model
    accuracy = metrics.accuracy_score(y_test, y_pred)
    print("Logistic Regression Accuracy:", accuracy)
    
def ModelAccuracy(X_train,)

def main():
    # Load data
    file_path = 'Fraud.csv'
    data = load_data(file_path)

    # Explore data
    explore_data(data)

    # Preprocess data
    data = preprocess_data(data)

    # Split and standardize data
    X, y = data.loc[:, data.columns != 'isFraud'], data['isFraud']
    X_train, X_test, y_train, y_test = split_and_standardize_data(X, y)

    # Train and evaluate models
    train_and_evaluate_naive_bayes(X_train, X_test, y_train, y_test)
    train_and_evaluate_logistic_regression(X_train, X_test, y_train, y_test)

if __name__ == "__main__":
    main()
# Out:
# Head:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
# Tail:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# ...
